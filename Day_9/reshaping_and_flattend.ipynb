# %%
import numpy as np

# %%
arr = np.array([[1,2,3],[4,5,6]])
print(arr, arr.shape)
# Out:
# [[1 2 3]
#  [4 5 6]] (2, 3)

# %% [markdown]
# ***Reshape array***

# %%
reshape = arr.reshape(3,2)
print(reshape, reshape.shape)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]] (3, 2)

# %% [markdown]
# **flatten**

# %%
print(reshape.flatten())
# Out:
# [1 2 3 4 5 6]
