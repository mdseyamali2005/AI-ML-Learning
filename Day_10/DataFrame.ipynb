# %%
import pandas as pd

# %%
print(pd.read_csv("employee_data.csv")) #like this read_json , read_excel
data = pd.read_csv("employee_data.csv")
data
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
print(data.head())#first 5 row print hobe
print()
print(data.tail())#last 5 row print hobe
print()
print(data.tail(7))#similarly we can use (3 or something another) for ger only this specific value
print()
print(data.sample(2))#for random value
print()
print(data.info())#for short information about data frame
print()
print(data.describe()) #for int data , calcutate some basic 
print()
print(data.shape)#first is row and then columns 
print()
print(data.columns)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
#
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000
#
#    ID    Name  Age Department  Salary
# 3   4   David   45  Marketing   91000
# 4   5     Eva   38         IT   65000
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000
#
#    ID   Name  Age Department  Salary
# 9  10  Julia   30    Finance   60000
# 8   9    Ian   35         IT   75000
#
# <class 'pandas.core.frame.DataFrame'>
# ...
