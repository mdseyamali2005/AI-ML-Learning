# %%
import pandas as pd

# %%
ser = pd.Series([3,2,5,54,2,6])
print(ser)
#indexing
print(ser[3])
# Out:
# 0     3
# 1     2
# 2     5
# 3    54
# 4     2
# 5     6
# dtype: int64
# 54

# %% [markdown]
# **index means the position and level means the position name**

# %%
ser1 = pd.Series([23,12,54,41,22,26], index = ["seyam","halim", "galib", "tamim", "farhan","bob"])#here index represent the position name or level
print(ser1)
#using level print
print(ser1["galib"])
#using index print
print(ser1[1])
#we can
# Out:
# seyam     23
# halim     12
# galib     54
# tamim     41
# farhan    22
# bob       26
# dtype: int64
# 54
# <ipython-input-16-180f31587338>:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(ser1[1])
# 12
