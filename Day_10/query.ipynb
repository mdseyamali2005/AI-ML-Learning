# %%
import pandas as pd

# %%
df = pd.read_csv("globalAirQuality.csv")
print(df.query("temperature > 37"))
aqi_value = 100
data = df.query("aqi > @aqi_value & temperature > 37")[["city", "aqi"]].copy() #we can menction any veriable using @
print(data)
