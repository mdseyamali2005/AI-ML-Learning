# %%
import pandas as pd

# %%
info = {
    "Name" : ["Seyam","Galib","Tamim"],
    "Cgpa" : [4,3.5,3.2]
}
data = pd.DataFrame(info)
print(data)
data
# Out:
#     Name  Cgpa
# 0  Seyam   4.0
# 1  Galib   3.5
# 2  Tamim   3.2
#     Name  Cgpa
# 0  Seyam   4.0
# 1  Galib   3.5
# 2  Tamim   3.2
