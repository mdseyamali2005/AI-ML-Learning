# %%
import pandas as pd

# %%
serie = pd.Series([2,3,4,62,5,6,3])
serie1 = pd.Series([21,13,24,62,53,16,23])
print(serie + serie1) #vectorized in series
serie[0] = 20
print(serie)
changed_serie = serie.drop(0) #remove first value from the Seires
print(changed_serie)
# Out:
# 0     23
# 1     16
# 2     28
# 3    124
# 4     58
# 5     22
# 6     26
# dtype: int64
# 0    20
# 1     3
# 2     4
# 3    62
# 4     5
# 5     6
# 6     3
# dtype: int64
# 1     3
# 2     4
# 3    62
# 4     5
# 5     6
# 6     3
# dtype: int64
