# %%
import json

# %%
def data_in(Name):
    with open(Name, "r") as f:
        data = json.load(f)
        return data

# %%
data = data_in("data.json")
print(data)
# Out:
# [{'name': 'Md Seyam Ali', 'rating': '5', 'feedback': 'I love it', 'age': '34'}, {'name': 'koli', 'rating': '3', 'feedback': 'Wow', 'age': '23'}, {'name': 'suborna', 'rating': '5', 'feedback': 'Great', 'age': '43'}, {'name': 'bonu', 'rating': '1', 'feedback': 'good job bro', 'age': '21'}]
